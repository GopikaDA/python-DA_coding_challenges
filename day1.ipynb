# %% [markdown]
# <a href="https://colab.research.google.com/github/GopikaDA/python-DA_coding_challenges/blob/main/day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  NumPy Arrays & Operations

# %% [markdown]
# ## Array Creation

# %%
import numpy as np

one_d_array = np.array([1,2,3,4,5,6,7])
one_d_array
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
print(one_d_array)
# Out:
# [1 2 3 4 5 6 7]

# %%
oned_array=np.arange(3,16,3)
oned_array
# Out:
# array([ 3,  6,  9, 12, 15])
